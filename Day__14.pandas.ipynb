# %%
import pandas as pd

# %%
weather_data=[("1/1/2024",32,6,"rain"),
             ("2/11/2014",35,7,"sunny")]

# %%
df= pd.DataFrame(weather_data ,\
                 columns=["date",'temperature','wind','climate'])

# %%
df
# Out:
#         date  temperature  wind climate
# 0   1/1/2024           32     6    rain
# 1  2/11/2014           35     7   sunny

# %%
df=pd.read_csv("C:\\Users\\niranjana\\Downloads\\auto-mpg.csv")

# %%
df.shape
# Out:
# (398, 9)

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
df.tail(2)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin     car name
# 396          82       1  ford ranger
# 397          82       1   chevy s-10

# %%
df["mpg"]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df['model year']
# Out:
# 0      70
# 1      70
# 2      70
# 3      70
# 4      70
#        ..
# 393    82
# 394    82
# 395    82
# 396    82
# 397    82
# Name: model year, Length: 398, dtype: int64

# %%
df.mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df[["car name"]]
# Out:
#                       car name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 393            ford mustang gl
# 394                  vw pickup
# 395              dodge rampage
# 396                ford ranger
# 397                 chevy s-10
#
# [398 rows x 1 columns]

# %%
df['car name']
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: car name, Length: 398, dtype: object

# %%
df.columns.tolist()
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model year',
#  'origin',
#  'car name']

# %%
df[["mpg", "car name"]]
# Out:
#       mpg                   car name
# 0    18.0  chevrolet chevelle malibu
# 1    15.0          buick skylark 320
# 2    18.0         plymouth satellite
# 3    16.0              amc rebel sst
# 4    17.0                ford torino
# ..    ...                        ...
# 393  27.0            ford mustang gl
# 394  44.0                  vw pickup
# 395  32.0              dodge rampage
# 396  28.0                ford ranger
# 397  31.0                 chevy s-10
#
# [398 rows x 2 columns]

# %%
new_df=df[['car name','weight']]

# %%
new_df.to_excel("C:\\Users\\niranjana\\OneDrive\\Desktop\\DSA\\output.xlsx",sheet_name='sheet 1')   #DSA FOLDE---->OUTPUT

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.shape
# Out:
# (398, 9)

# %%
df_sample=df.sample(10)

# %%
df_sample
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 94   13.0          8         440.0        215    4735          11.0
# 316  19.1          6         225.0         90    3381          18.7
# 98   16.0          6         250.0        100    3278          18.0
# 274  20.3          5         131.0        103    2830          15.9
# 258  20.6          6         231.0        105    3380          15.8
# 78   21.0          4         120.0         87    2979          19.5
# 10   15.0          8         383.0        170    3563          10.0
# 61   21.0          4         122.0         86    2226          16.5
# 97   18.0          6         225.0        105    3121          16.5
# 229  16.0          8         400.0        180    4220          11.1
#
#      model year  origin                      car name
# 94           73       1  chrysler new yorker brougham
# 316          80       1                   dodge aspen
# 98           73       1         chevrolet nova custom
# ...

# %%
g=df.groupby('model year')

# %%
g.max()
# Out:
#              mpg  cylinders  displacement horsepower  weight  acceleration  \
# model year
# 70          27.0          8         455.0         97    4732          20.5
# 71          35.0          8         400.0          ?    5140          20.5
# 72          28.0          8         429.0         97    4633          23.5
# 73          29.0          8         455.0         95    4997          21.0
# 74          32.0          8         350.0          ?    4699          21.0
# 75          33.0          8         400.0         98    4668          21.0
# 76          33.0          8         351.0         95    4380          22.2
# 77          36.0          8         400.0         98    4335          19.0
# 78          43.1          8         318.0         97    4080          21.5
# 79          37.3          8         360.0         90    4360          24.8
# 80          46.6          6         225.0          ?    3381          23.7
# ...

# %%
for x, model_df in g: 
    print(x)
    print(model_df)
# Out:
# 70
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 1   15.0          8         350.0        165    3693          11.5
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# ...

# %%
india_weather=pd.DataFrame({'city':['newyork','chicago','seatle'],
                             "temperature":[21,13,35],
                             "humidity":[68,65,75],
                            })

# %%
india_weather
# Out:
#       city  temperature  humidity
# 0  newyork           21        68
# 1  chicago           13        65
# 2   seatle           35        75

# %%
us_weather=pd.DataFrame({'city':['mumbai','bangalore','tvm'],
                             "temperature":[30,13,45],
                             "humidity":[66,65,56],})

# %%
us_weather
# Out:
#         city  temperature  humidity
# 0     mumbai           30        66
# 1  bangalore           13        65
# 2        tvm           45        56

# %%
us_weather['temperature']<30
# Out:
# 0    False
# 1     True
# 2    False
# Name: temperature, dtype: bool

# %%
weather_us_india=pd.concat([india_weather,us_weather],ignore_index=True)

# %%
weather_us_india
# Out:
#         city  temperature  humidity
# 0    newyork           21        68
# 1    chicago           13        65
# 2     seatle           35        75
# 3     mumbai           30        66
# 4  bangalore           13        65
# 5        tvm           45        56

# %%
weather_us_india[weather_us_india["temperature"]<30]
# Out:
#         city  temperature  humidity
# 0    newyork           21        68
# 1    chicago           14        65
# 3     mumbai           27        66
# 4  bangalore           16        65

# %%
pd.concat([us_weather, india_weather], axis=1)
# Out:
#         city  temperature  humidity     city  temperature  humidity
# 0     mumbai           30        66  newyork           21        68
# 1  bangalore           13        65  chicago           13        65
# 2        tvm           45        56   seatle           35        75

# %%
pd.merge(india_weather,us_weather, on='temperature')             #same temprature
# Out:
#     city_x  temperature  humidity_x     city_y  humidity_y
# 0  chicago           13          65  bangalore          65

# %%
weather_us_india["temperature"]<30
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# Name: temperature, dtype: bool

# %%
df=pd.DataFrame([1, 2,3 ,4],index=[49,48,12,13])

# %%
df
# Out:
#     0
# 49  1
# 48  2
# 12  3
# 13  4

# %%
df.loc[49]
# Out:
# 0    1
# Name: 49, dtype: int64

# %%
df.iloc[2]
# Out:
# 0    3
# Name: 12, dtype: int64

# %%
city1=pd.Series([12,-6,8,-3], index=['day1', 'day2', 'day3', 'day4'])

# %%
city1
# Out:
# day1    12
# day2    -6
# day3     8
# day4    -3
# dtype: int64

# %%
#to find missing value

# %%
city1.isna()
# Out:
# day1    False
# day2    False
# day3    False
# day4    False
# dtype: bool

# %%
df.isna().sum()
# Out:
# 0    0
# dtype: int64

# %%
city1*3
# Out:
# day1    36
# day2   -18
# day3    24
# day4    -9
# dtype: int64

# %%
df["car name"].unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'ford pinto', 'plymouth satellite custom', 'ford torino 500',
#        'amc matador', 'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
# ...

# %%
df["cylinders"].value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
car_new= df.drop(["origin", "car name"],axis=1)

# %%
car_new.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year
# count  398.000000
# mean    76.010050
# std      3.697627
# min     70.000000
# 25%     73.000000
# 50%     76.000000
# 75%     79.000000
# max     82.000000

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
#city1.isna()
city1[~city1.isna()]
# Out:
# day1    12
# day2    -6
# day3     8
# day4    -3
# dtype: int64
